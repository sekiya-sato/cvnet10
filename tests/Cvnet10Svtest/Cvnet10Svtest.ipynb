// %%
#r "nuget:Grpc.Net.Client, 2.76.0"
#r "nuget:Newtonsoft.Json, 13.0.4"
#r "../../CodeShare/bin/Debug/net10.0/CodeShare.dll"
#r "../../Cvnet10Base/bin/Debug/net10.0/Cvnet10Base.dll"
using Cvnet10Base;
Console.WriteLine(Common.Version);

// %%
dotnet run --project Cvnet10Svtest.csproj --configuration Debug
