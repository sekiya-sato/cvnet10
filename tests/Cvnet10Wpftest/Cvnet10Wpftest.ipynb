// %%
#r "nuget:CommunityToolkit.Mvvm, 8.4.0"
#r "nuget:Microsoft.Data.Sqlite, 10.0.2"
#r "nuget:NPoco, 6.1.0"
#r "nuget:Oracle.ManagedDataAccess.Core, 23.26.0"
using Microsoft.Data.Sqlite;
using NPoco;
using System;
using var connection = new SqliteConnection("Data Source=:memory:");
connection.Open();
var db = new Database(connection);
Console.WriteLine("WPF test harness ready");

// %%
dotnet build Cvnet10Wpftest.csproj --configuration Debug
